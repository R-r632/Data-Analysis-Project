# %%
import pandas as pd

# %%
# Data for the total awards won by a film editor
data_film_editors = [
    {"Name": "Thelma Schoonmaker", "Country": "USA", "Race": "White", "Gender": "Female", "Occupation": "Film Editor", "Awards Won": 3},
    {"Name": "Michael Kahn", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Film Editor", "Awards Won": 3},
    {"Name": "Daniel Mandell", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Film Editor", "Awards Won": 3},
    {"Name": "Ralph Dawson", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Film Editor", "Awards Won": 3},
    {"Name": "Arthur Schmidt", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Film Editor", "Awards Won": 2},
    {"Name": "Francis D. Lyon", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Film Editor", "Awards Won": 2},
    {"Name": "William Reynolds", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Film Editor", "Awards Won": 2},
    {"Name": "Hugh S. Fowler", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Film Editor", "Awards Won": 2},
    {"Name": "Paul Hirsch", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Film Editor", "Awards Won": 2},
    {"Name": "Robert Wise", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Film Editor/Director", "Awards Won": 2}
]

# Create DataFrame for film editor awards
df_film_editors = pd.DataFrame(data_film_editors)

# Sort by Awards Won
df_film_editors_sorted = df_film_editors.sort_values(by='Awards Won', ascending=False)
df_film_editors_sorted

# Save to Excel
df_film_editors_sorted.to_excel('Collected Datasets/Film Editorss Awards.xlsx', index=False)

#file_path_film_editors

# %%
data_cinematographers = [
    {"Name": "Leon Shamroy", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Cinematographer", "Awards Won": 4},
    {"Name": "Joseph Ruttenberg", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Cinematographer", "Awards Won": 4},
    {"Name": "Conrad L. Hall", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Cinematographer", "Awards Won": 3},
    {"Name": "Robert L. Surtees", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Cinematographer", "Awards Won": 3},
    {"Name": "Freddie Young", "Country": "UK", "Race": "White", "Gender": "Male", "Occupation": "Cinematographer", "Awards Won": 3},
    {"Name": "Winton C. Hoch", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Cinematographer", "Awards Won": 3},
    {"Name": "Arthur C. Miller", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Cinematographer", "Awards Won": 3},
    {"Name": "Harry Stradling Sr.", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Cinematographer", "Awards Won": 2},
    {"Name": "John Toll", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Cinematographer", "Awards Won": 2},
    {"Name": "Emmanuel Lubezki", "Country": "Mexico", "Race": "Hispanic", "Gender": "Male", "Occupation": "Cinematographer", "Awards Won": 2}
]

df_cinematographers = pd.DataFrame(data_cinematographers)

df_cinematographers_sorted = df_cinematographers.sort_values(by='Awards Won', ascending=False)
df_cinematographers_sorted

df_cinematographers_sorted.to_excel('Collected Datasets/Cinematographers.xlsx', index=False)

# %%
data_composers = [
    {"Name": "Alfred Newman", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Composer", "Awards Won": 9},
    {"Name": "Alan Menken", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Composer", "Awards Won": 8},
    {"Name": "John Williams", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Composer", "Awards Won": 5},
    {"Name": "John Barry", "Country": "UK", "Race": "White", "Gender": "Male", "Occupation": "Composer", "Awards Won": 5},
    {"Name": "Johnny Mercer", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Composer", "Awards Won": 4},
    {"Name": "Andre Previn", "Country": "Germany", "Race": "White", "Gender": "Male", "Occupation": "Composer", "Awards Won": 4},
    {"Name": "Maurice Jarre", "Country": "France", "Race": "White", "Gender": "Male", "Occupation": "Composer", "Awards Won": 3},
    {"Name": "Max Steiner", "Country": "Austria", "Race": "White", "Gender": "Male", "Occupation": "Composer", "Awards Won": 3},
    {"Name": "Dimitri Tiomkin", "Country": "Russia", "Race": "White", "Gender": "Male", "Occupation": "Composer", "Awards Won": 3},
    {"Name": "Miklós Rózsa", "Country": "Hungary", "Race": "White", "Gender": "Male", "Occupation": "Composer", "Awards Won": 3}
]

df_composers = pd.DataFrame(data_composers)

df_composers_sorted = df_composers.sort_values(by='Awards Won', ascending=False)

df_composers_sorted.to_excel('Collected Datasets/Composers.xlsx', index=False)

# %%
# Data for the total awards won by an art director or production designer
data_art_directors = [
    {"Name": "Cedric Gibbons", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Art Director", "Awards Won": 11},
    {"Name": "Lyle R. Wheeler", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Art Director", "Awards Won": 5},
    {"Name": "William A. Horning", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Art Director", "Awards Won": 4},
    {"Name": "Hans Dreier", "Country": "Germany", "Race": "White", "Gender": "Male", "Occupation": "Art Director", "Awards Won": 3},
    {"Name": "Hal Pereira", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Art Director", "Awards Won": 3},
    {"Name": "Dante Ferretti", "Country": "Italy", "Race": "White", "Gender": "Male", "Occupation": "Production Designer", "Awards Won": 3},
    {"Name": "Richard Day", "Country": "Canada", "Race": "White", "Gender": "Male", "Occupation": "Art Director", "Awards Won": 3},
    {"Name": "Wiard Ihnen", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Art Director", "Awards Won": 2},
    {"Name": "John DeCuir", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Art Director", "Awards Won": 2},
    {"Name": "Stuart Craig", "Country": "UK", "Race": "White", "Gender": "Male", "Occupation": "Production Designer", "Awards Won": 3}
]

# Data for the total awards won by a costume designer
data_costume_designers = [
    {"Name": "Edith Head", "Country": "USA", "Race": "White", "Gender": "Female", "Occupation": "Costume Designer", "Awards Won": 8},
    {"Name": "Irene Sharaff", "Country": "USA", "Race": "White", "Gender": "Female", "Occupation": "Costume Designer", "Awards Won": 5},
    {"Name": "Colleen Atwood", "Country": "USA", "Race": "White", "Gender": "Female", "Occupation": "Costume Designer", "Awards Won": 4},
    {"Name": "Milena Canonero", "Country": "Italy", "Race": "White", "Gender": "Female", "Occupation": "Costume Designer", "Awards Won": 4},
    {"Name": "Charles Le Maire", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Costume Designer", "Awards Won": 3},
    {"Name": "Sandy Powell", "Country": "UK", "Race": "White", "Gender": "Female", "Occupation": "Costume Designer", "Awards Won": 3},
    {"Name": "Dorothy Jeakins", "Country": "USA", "Race": "White", "Gender": "Female", "Occupation": "Costume Designer", "Awards Won": 3},
    {"Name": "Piero Tosi", "Country": "Italy", "Race": "White", "Gender": "Male", "Occupation": "Costume Designer", "Awards Won": 2},
    {"Name": "Jenny Beavan", "Country": "UK", "Race": "White", "Gender": "Female", "Occupation": "Costume Designer", "Awards Won": 2},
    {"Name": "Eiko Ishioka", "Country": "Japan", "Race": "Asian", "Gender": "Female", "Occupation": "Costume Designer", "Awards Won": 2}
]

# Data for the total awards won by a makeup artist
data_makeup_artists = [
    {"Name": "Rick Baker", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Makeup Artist", "Awards Won": 7},
    {"Name": "Ve Neill", "Country": "USA", "Race": "White", "Gender": "Female", "Occupation": "Makeup Artist", "Awards Won": 3},
    {"Name": "Greg Cannom", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Makeup Artist", "Awards Won": 3},
    {"Name": "David LeRoy Anderson", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Makeup Artist", "Awards Won": 2},
    {"Name": "Tami Lane", "Country": "USA", "Race": "White", "Gender": "Female", "Occupation": "Makeup Artist", "Awards Won": 2},
    {"Name": "Peter Owen", "Country": "UK", "Race": "White", "Gender": "Male", "Occupation": "Makeup Artist", "Awards Won": 2},
    {"Name": "Kazu Hiro", "Country": "Japan", "Race": "Asian", "Gender": "Male", "Occupation": "Makeup Artist", "Awards Won": 2},
    {"Name": "Mark Coulier", "Country": "UK", "Race": "White", "Gender": "Male", "Occupation": "Makeup Artist", "Awards Won": 2},
    {"Name": "John Caglione Jr.", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Makeup Artist", "Awards Won": 1},
    {"Name": "Joel Harlow", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Makeup Artist", "Awards Won": 1}
]


df_art_directors = pd.DataFrame(data_art_directors)
df_costume_designers = pd.DataFrame(data_costume_designers)
df_makeup_artists = pd.DataFrame(data_makeup_artists)

df_art_directors_sorted = df_art_directors.sort_values(by='Awards Won', ascending=False)
df_costume_designers_sorted = df_costume_designers.sort_values(by='Awards Won', ascending=False)
df_makeup_artists_sorted = df_makeup_artists.sort_values(by='Awards Won', ascending=False)

df_art_directors_sorted.to_excel('Collected Datasets/Art Directors.xlsx', index=False)
df_costume_designers_sorted.to_excel('Collected Datasets/Costume Designer.xlsx', index=False)
df_makeup_artists_sorted.to_excel('Collected Datasets/Makeup Artist.xlsx', index=False)

# %%
# Data for the total awards won by visual effects artists
data_visual_effects_artists = [
    {"Name": "Dennis Muren", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Visual Effects Artist", "Awards Won": 8},
    {"Name": "Ken Ralston", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Visual Effects Artist", "Awards Won": 5},
    {"Name": "Richard Edlund", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Visual Effects Artist", "Awards Won": 4},
    {"Name": "Joe Letteri", "Country": "New Zealand", "Race": "White", "Gender": "Male", "Occupation": "Visual Effects Artist", "Awards Won": 4},
    {"Name": "Richard Taylor", "Country": "New Zealand", "Race": "White", "Gender": "Male", "Occupation": "Visual Effects Artist", "Awards Won": 4},
    {"Name": "John Knoll", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Visual Effects Artist", "Awards Won": 3},
    {"Name": "Jim Rygiel", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Visual Effects Artist", "Awards Won": 3},
    {"Name": "Ben Burtt", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Sound Designer/Visual Effects Artist", "Awards Won": 2},
    {"Name": "John Dykstra", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Visual Effects Artist", "Awards Won": 2},
    {"Name": "Paul Franklin", "Country": "UK", "Race": "White", "Gender": "Male", "Occupation": "Visual Effects Artist", "Awards Won": 2}
]

# Data for the total awards won by animated feature film directors
data_animated_film_directors = [
    {"Name": "Pete Docter", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 3},
    {"Name": "Andrew Stanton", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 2},
    {"Name": "Lee Unkrich", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 2},
    {"Name": "Brad Bird", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 2},
    {"Name": "Chris Buck", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 1},
    {"Name": "Jennifer Lee", "Country": "USA", "Race": "White", "Gender": "Female", "Occupation": "Director", "Awards Won": 1},
    {"Name": "Rich Moore", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 1},
    {"Name": "Byron Howard", "Country": "USA", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 1},
    {"Name": "Peter Ramsey", "Country": "USA", "Race": "Black", "Gender": "Male", "Occupation": "Director", "Awards Won": 1},
    {"Name": "Jennifer Yuh Nelson", "Country": "USA", "Race": "Asian", "Gender": "Female", "Occupation": "Director", "Awards Won": 0}
]

# Data for the total awards won by foreign directors for best foreign language films
data_foreign_directors = [
    {"Name": "Federico Fellini", "Country": "Italy", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 4},
    {"Name": "Vittorio De Sica", "Country": "Italy", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 4},
    {"Name": "Ingmar Bergman", "Country": "Sweden", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 3},
    {"Name": "Akira Kurosawa", "Country": "Japan", "Race": "Asian", "Gender": "Male", "Occupation": "Director", "Awards Won": 1},
    {"Name": "Asghar Farhadi", "Country": "Iran", "Race": "Asian", "Gender": "Male", "Occupation": "Director", "Awards Won": 2},
    {"Name": "Pedro Almodóvar", "Country": "Spain", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 1},
    {"Name": "Michael Haneke", "Country": "Austria", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 1},
    {"Name": "Ang Lee", "Country": "Taiwan", "Race": "Asian", "Gender": "Male", "Occupation": "Director", "Awards Won": 1},
    {"Name": "Florian Henckel von Donnersmarck", "Country": "Germany", "Race": "White", "Gender": "Male", "Occupation": "Director", "Awards Won": 1},
    {"Name": "Alfonso Cuarón", "Country": "Mexico", "Race": "Hispanic", "Gender": "Male", "Occupation": "Director", "Awards Won": 1}
]


df_visual_effects_artists = pd.DataFrame(data_visual_effects_artists)
df_animated_film_directors = pd.DataFrame(data_animated_film_directors)
df_foreign_directors = pd.DataFrame(data_foreign_directors)

df_visual_effects_artists_sorted = df_visual_effects_artists.sort_values(by='Awards Won', ascending=False)
df_animated_film_directors_sorted = df_animated_film_directors.sort_values(by='Awards Won', ascending=False)
df_foreign_directors_sorted = df_foreign_directors.sort_values(by='Awards Won', ascending=False)

df_visual_effects_artists_sorted.to_excel('Collected Datasets/Visual Effects.xlsx', index=False)
df_animated_film_directors_sorted.to_excel('Collected Datasets/Animated Features.xlsx', index=False)
df_foreign_directors_sorted.to_excel('Collected Datasets/Foreign Directors.xlsx', index=False)

# %%
data_countries_awards = [
    {"Name of Country": "France", "Continent": "Europe", "Common Language": "French", "Awards Won": 12, "Nominations": 41},
    {"Name of Country": "Italy", "Continent": "Europe", "Common Language": "Italian", "Awards Won": 14, "Nominations": 33},
    {"Name of Country": "Germany", "Continent": "Europe", "Common Language": "German", "Awards Won": 3, "Nominations": 13},
    {"Name of Country": "Canada", "Continent": "North America", "Common Language": "English", "Awards Won": 1, "Nominations": 7},
    {"Name of Country": "Japan", "Continent": "Asia", "Common Language": "Japanese", "Awards Won": 5, "Nominations": 18},
    {"Name of Country": "Spain", "Continent": "Europe", "Common Language": "Spanish", "Awards Won": 4, "Nominations": 21},
    {"Name of Country": "Soviet Union", "Continent": "Asia", "Common Language": "Russian", "Awards Won": 3, "Nominations": 9},
    {"Name of Country": "Sweden", "Continent": "Europe", "Common Language": "Swedish", "Awards Won": 3, "Nominations": 16},
    {"Name of Country": "Israel", "Continent": "Europe", "Common Language": "Hebrew", "Awards Won": 0, "Nominations": 10}
]

data_countries_nominations = [
    {"Name of Country": "France", "Continent": "Europe", "Common Language": "French", "Nominations": 41, "Submissions": 71},
    {"Name of Country": "Italy", "Continent": "Europe", "Common Language": "Italian", "Nominations": 33, "Submissions": 70},
    {"Name of Country": "Germany", "Continent": "Europe", "Common Language": "German", "Nominations": 13, "Submissions": 33},
    {"Name of Country": "Canada", "Continent": "North America", "Common Language": "English", "Nominations": 7, "Submissions": 49},
    {"Name of Country": "Japan", "Continent": "Asia", "Common Language": "Japanese", "Nominations": 18, "Submissions": 70},
    {"Name of Country": "Spain", "Continent": "Europe", "Common Language": "Spanish", "Nominations": 21, "Submissions": 66},
    {"Name of Country": "Soviet Union", "Continent": "Asia", "Common Language": "Russian", "Nominations": 9, "Submissions": 24},
    {"Name of Country": "Sweden", "Continent": "Europe", "Common Language": "Swedish", "Nominations": 13, "Submissions": 63},
    {"Name of Country": "Israel", "Continent": "Europe", "Common Language": "Hebrew", "Nominations": 10, "Submissions": 56}
]

df_countries_awards = pd.DataFrame(data_countries_awards)
df_countries_nominations = pd.DataFrame(data_countries_nominations)
df_countries_awards_sorted = df_countries_awards.sort_values(by='Awards Won', ascending=False)
df_countries_nominations_sorted = df_countries_nominations.sort_values(by='Nominations', ascending=False)
df_countries_awards_sorted.to_excel('Collected Datasets/Countries Awards.xlsx', index=False)
df_countries_nominations_sorted.to_excel('Collected Datasets/Countries Nominations.xlsx', index=False)

# %%
data_foreign_film_awards = [
    {"Film":"Parasite","Director":"Bong-Joon Hoon","Country": "South Korea", "Continent": "Asia", "Common Language": "Korean", "Awards Won": 4, "Nominations": 6},
    {"Film":"Crouching Tigen, Hidden Dragon","Director":"Ang Lee","Country": "Taiwan", "Continent": "Asia", "Common Language": "Madarin", "Awards Won": 4, "Nominations": 10},
    {"Film":"Life Is Beautiful","Director":"Roberto Beningni","Country": "Italy", "Continent": "Europe", "Common Language": "Italian", "Awards Won": 3, "Nominations": 7},
    {"Film":"Roma","Director":"Alfonso Cuaron","Country": "Mexico", "Continent": "North America", "Common Language": "Spanish", "Awards Won": 3, "Nominations": 10},
    {"Film":"Fanny And Alexander","Director":"Ingmar Berman","Country": "Sweden", "Continent": "Europe", "Common Language": "Swedish", "Awards Won": 4, "Nominations": 4},
    {"Film":"8(1/2)","Director":"Federico Fellini","Country": "Italy", "Continent": "Europe", "Common Language": "Italian", "Awards Won": 2, "Nominations": 4},
    
]

data_foreign_film_nominations = [
    {"Film":"Parasite","Director":"Bong-Joon Hoon","Country": "South Korea", "Continent": "Asia", "Common Language": "Korean", "Nominations": 6},
    {"Film":"Crouching Tigen, Hidden Dragon","Director":"Ang Lee","Country": "Taiwan", "Continent": "Asia", "Common Language": "Madarin", "Nominations": 10},
    {"Film":"Life Is Beautiful","Director":"Roberto Beningni","Country": "Italy", "Continent": "Europe", "Common Language": "Italian", "Nominations": 7},
    {"Film":"Roma","Director":"Alfonso Cuaron","Country": "Mexico", "Continent": "North America", "Common Language": "Spanish", "Nominations": 10},
    {"Film":"Pan's Labrynth","Director":"Guillermo Del Toro","Country": "Mexico", "Continent": "Europe", "Common Language": "Spanish", "Nominations": 6},
    {"Film":"Amour","Director":"Micheal Haneke","Country": "France", "Continent": "Europe", "Common Language": "French", "Nominations": 5},
    
]

df_foreign_film_awards = pd.DataFrame(data_foreign_film_awards)
df_foreign_film_nominations = pd.DataFrame(data_foreign_film_nominations)
df_foreign_film_awards_sorted = df_foreign_film_awards.sort_values(by='Awards Won', ascending=False)
df_foreign_film_nominations_sorted = df_foreign_film_nominations.sort_values(by='Nominations', ascending=False)
df_foreign_film_awards_sorted.to_excel('Collected Datasets/Non English Awards.xlsx', index=False)
df_foreign_film_nominations_sorted.to_excel('Collected Datasets/Non English Nominations.xlsx', index=False)

# %%
import pandas as pd
data_highest_box_office = [
    {"Film Name": "Titanic", "Release Year": 1997, "Awarded Year": 1998, "Oscar Nominations": 14, "Director": "James Cameron", "Producer": "James Cameron", "Production Company": "20th Century Fox", "Distributor": "Paramount Pictures", "Oscar Wins": 11, "Budget": 200_000_000, "Box Office": 2_187_463_944, "Box Office Adjusted to Inflation": 3_978_000_000},
    {"Film Name": "The Lord of the Rings: The Return of the King", "Release Year": 2003, "Awarded Year": 2004, "Oscar Nominations": 11, "Director": "Peter Jackson", "Producer": "Peter Jackson", "Production Company": "New Line Cinema", "Distributor": "New Line Cinema", "Oscar Wins": 11, "Budget": 94_000_000, "Box Office": 1_142_219_401, "Box Office Adjusted to Inflation": 1_577_000_000},
    {"Film Name": "Forrest Gump", "Release Year": 1994, "Awarded Year": 1995, "Oscar Nominations": 13, "Director": "Robert Zemeckis", "Producer": "Wendy Finerman", "Production Company": "Paramount Pictures", "Distributor": "Paramount Pictures", "Oscar Wins": 6, "Budget": 55_000_000, "Box Office": 678_226_465, "Box Office Adjusted to Inflation": 1_243_000_000},
    {"Film Name": "The Godfather", "Release Year": 1972, "Awarded Year": 1973, "Oscar Nominations": 10, "Director": "Francis Ford Coppola", "Producer": "Albert S. Ruddy", "Production Company": "Paramount Pictures", "Distributor": "Paramount Pictures", "Oscar Wins": 3, "Budget": 6_000_000, "Box Office": 246_120_974, "Box Office Adjusted to Inflation": 1_225_000_000},
    {"Film Name": "Ben-Hur", "Release Year": 1959, "Awarded Year": 1960, "Oscar Nominations": 12, "Director": "William Wyler", "Producer": "Sam Zimbalist", "Production Company": "Metro-Goldwyn-Mayer", "Distributor": "Loew's Inc.", "Oscar Wins": 11, "Budget": 15_000_000, "Box Office": 146_900_000, "Box Office Adjusted to Inflation": 1_211_000_000},
    {"Film Name": "West Side Story", "Release Year": 1961, "Awarded Year": 1962, "Oscar Nominations": 11, "Director": "Robert Wise", "Producer": "Robert Wise", "Production Company": "United Artists", "Distributor": "United Artists", "Oscar Wins": 10, "Budget": 6_000_000, "Box Office": 44_100_000, "Box Office Adjusted to Inflation": 940_000_000},
    {"Film Name": "Rocky", "Release Year": 1976, "Awarded Year": 1977, "Oscar Nominations": 10, "Director": "John G. Avildsen", "Producer": "Irwin Winkler", "Production Company": "Chartoff-Winkler Productions", "Distributor": "United Artists", "Oscar Wins": 3, "Budget": 1_100_000, "Box Office": 225_000_000, "Box Office Adjusted to Inflation": 965_000_000},
    {"Film Name": "Gone with the Wind", "Release Year": 1939, "Awarded Year": 1940, "Oscar Nominations": 13, "Director": "Victor Fleming", "Producer": "David O. Selznick", "Production Company": "Selznick International Pictures", "Distributor": "Metro-Goldwyn-Mayer", "Oscar Wins": 8, "Budget": 3_900_000, "Box Office": 198_676_459, "Box Office Adjusted to Inflation": 3_400_000_000},
    {"Film Name": "The Sound of Music", "Release Year": 1965, "Awarded Year": 1966, "Oscar Nominations": 10, "Director": "Robert Wise", "Producer": "Robert Wise", "Production Company": "20th Century Fox", "Distributor": "20th Century Fox", "Oscar Wins": 5, "Budget": 8_200_000, "Box Office": 286_214_286, "Box Office Adjusted to Inflation": 2_514_000_000},
    {"Film Name": "The Godfather Part II", "Release Year": 1974, "Awarded Year": 1975, "Oscar Nominations": 11, "Director": "Francis Ford Coppola", "Producer": "Francis Ford Coppola", "Production Company": "Paramount Pictures", "Distributor": "Paramount Pictures", "Oscar Wins": 6, "Budget": 13_000_000, "Box Office": 47_834_595, "Box Office Adjusted to Inflation": 245_000_000},
    {"Film Name": "Braveheart", "Release Year": 1995, "Awarded Year": 1996, "Oscar Nominations": 10, "Director": "Mel Gibson", "Producer": "Mel Gibson", "Production Company": "Icon Productions", "Distributor": "Paramount Pictures", "Oscar Wins": 5, "Budget": 72_000_000, "Box Office": 210_409_945, "Box Office Adjusted to Inflation": 375_000_000},
    {"Film Name": "Gladiator", "Release Year": 2000, "Awarded Year": 2001, "Oscar Nominations": 12, "Director": "Ridley Scott", "Producer": "Douglas Wick", "Production Company": "DreamWorks Pictures", "Distributor": "Universal Pictures", "Oscar Wins": 5, "Budget": 103_000_000, "Box Office": 460_583_960, "Box Office Adjusted to Inflation": 700_000_000},
    {"Film Name": "Chicago", "Release Year": 2002, "Awarded Year": 2003, "Oscar Nominations": 13, "Director": "Rob Marshall", "Producer": "Martin Richards", "Production Company": "Miramax Films", "Distributor": "Miramax Films", "Oscar Wins": 6, "Budget": 45_000_000, "Box Office": 306_776_732, "Box Office Adjusted to Inflation": 425_000_000},
    {"Film Name": "Rain Man", "Release Year": 1988, "Awarded Year": 1989, "Oscar Nominations": 8, "Director": "Barry Levinson", "Producer": "Mark Johnson", "Production Company": "United Artists", "Distributor": "MGM/UA Entertainment", "Oscar Wins": 4, "Budget": 25_000_000, "Box Office": 354_825_435, "Box Office Adjusted to Inflation": 750_000_000},
    {"Film Name": "Platoon", "Release Year": 1986, "Awarded Year": 1987, "Oscar Nominations": 8, "Director": "Oliver Stone", "Producer": "Arnold Kopelson", "Production Company": "Hemdale Film Corporation", "Distributor": "Orion Pictures", "Oscar Wins": 4, "Budget": 6_000_000, "Box Office": 138_530_565, "Box Office Adjusted to Inflation": 350_000_000},
    {"Film Name": "Dances with Wolves", "Release Year": 1990, "Awarded Year": 1991, "Oscar Nominations": 12, "Director": "Kevin Costner", "Producer": "Jim Wilson", "Production Company": "Tig Productions", "Distributor": "Orion Pictures", "Oscar Wins": 7, "Budget": 22_000_000, "Box Office": 424_208_848, "Box Office Adjusted to Inflation": 830_000_000},
    {"Film Name": "Schindler's List", "Release Year": 1993, "Awarded Year": 1994, "Oscar Nominations": 12, "Director": "Steven Spielberg", "Producer": "Steven Spielberg", "Production Company": "Amblin Entertainment", "Distributor": "Universal Pictures", "Oscar Wins": 7, "Budget": 22_000_000, "Box Office": 322_161_245, "Box Office Adjusted to Inflation": 600_000_000},
    {"Film Name": "No Country for Old Men", "Release Year": 2007, "Awarded Year": 2008, "Oscar Nominations": 8, "Director": "Joel Coen", "Producer": "Ethan Coen", "Production Company": "Paramount Vantage", "Distributor": "Miramax Films", "Oscar Wins": 4, "Budget": 25_000_000, "Box Office": 171_161_245, "Box Office Adjusted to Inflation": 352_000_000}
]

df_highest_box_office = pd.DataFrame(data_highest_box_office)
df_highest_box_office.to_excel('Collected Datasets/Box Office Collected.xlsx', index=False)
